# %% [markdown]
# # Luminosity Distance vs Redshift graph using for loop (Trial plot)

# %%
import numpy as np
import scipy as sp
from scipy.integrate import quad
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']= (15,10)
c=299792458
H=70
def f(z):
    return 1/(H*((1+z)**3)**0.5)
for b in np.arange(1,10,.1):
    y=(1+b)*c*(quad(f,0,b)[0])*(10**(-3))
    plt.plot(b,y,'c.')
plt.plot(b,y,'c.', label= '$\Omega_o$=1, $\Omega_\Lambda$=0')
xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r"Luminosity Distance ($D_L$) in Mpc")
thetitle=plt.title("Luminosity Distance vs Redshift Graph"); thetitle.set_fontweight('bold')
    
def f(z):
    return 1/(H*(0.7*(1+z)**3 + 0.3)**0.5)
for b in np.arange(1,10,.1):
    y=(1+b)*c*(quad(f,0,b)[0])*(10**(-3))
    plt.plot(b,y,'g.')
plt.plot(b,y,'g.', label='$\Omega_o$=0.7, $\Omega_\Lambda$=0.3')
      
def f(z):
    return 1/(H*(0.5*(1+z)**3 + 0.5)**0.5)
for b in np.arange(1,10,.1):
    y=(1+b)*c*(quad(f,0,b)[0])*(10**(-3))
    plt.plot(b,y,'y.')
plt.plot(b,y,'y.', label= '$\Omega_o$=0.5, $\Omega_\Lambda$=0.5')

def f(z):
    return 1/(H*(0.3*(1+z)**3 + 0.7)**0.5)
for b in np.arange(1,10,.1):
    y=(1+b)*c*(quad(f,0,b)[0])*(10**(-3))
    plt.plot(b,y,'b.')
plt.plot(b,y,'b.', label= '$\Omega_o$=0.3, $\Omega_\Lambda$=0.7')
 
def f(z):
    return 1/(H*(0.1*(1+z)**3 + 0.9)**0.5)
for b in np.arange(1,10,.1):
    y=(1+b)*c*(quad(f,0,b)[0])*(10**(-3))
    plt.plot(b,y,'r.')
plt.plot(b,y,'r.',label= '$\Omega_o$=0.1, $\Omega_\Lambda$=0.9')

def f(z):
    return 1/(H*(0*(1+z)**3 + 1)**0.5)
for b in np.arange(1,10,.1):
    y=(1+b)*c*(quad(f,0,b)[0])*(10**(-3))
    plt.plot(b,y,'m.')
plt.plot(b,y,'m.', label= '$\Omega_o$=0, $\Omega_\Lambda$=1')
plt.legend()

# z=np.arange(1,10,.001)
# def f(z):
#     return 1/(H*((1+z)**3)**0.5)
# y=(1+10)*c*(quad(f,0,10)[0])
# plt.plot(z,y)




# y=(1+x)*c*(quad(f,0,10)[0])
# plt.plot(x,y)


# i=quad(f,0,3)[0]
# print (i)
plt.show()

# %% [markdown]
# # Luminosity Distance vs Redshift graph for various Cosmology Density parameters

# %%
import numpy as np
import scipy as sp
from scipy import integrate
from scipy.integrate import quad
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']= (15,10)
c=299792458
H=70
u=np.arange(1,10,.1)
om=1
omd=1-om


def f(z):
    return 1/(H*(om*(1+z)**3 + omd)**0.5)
y= (1+u)*(10**(-3))*c*[integrate.quad(f, 0, t)[0] for t in u]
plt.plot(u,y,label= '$\Omega_o$=1, $\Omega_\Lambda$=0')
xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r"Luminosity Distance ($D_L$) in Mpc")
thetitle=plt.title("Luminosity Distance vs Redshift Graph"); thetitle.set_fontweight('bold')

om=0.7
omd=1-om

def f(z):
    return 1/(H*(om*(1+z)**3 + omd)**0.5)
y= (1+u)*(10**(-3))*c*[integrate.quad(f, 0, t)[0] for t in u]
plt.plot(u,y,label= '$\Omega_o$=0.7, $\Omega_\Lambda$=0.3')

om=0.5
omd=1-om

def f(z):
    return 1/(H*(om*(1+z)**3 + omd)**0.5)
y= (1+u)*(10**(-3))*c*[integrate.quad(f, 0, t)[0] for t in u]
plt.plot(u,y,label='$\Omega_o$=0.5, $\Omega_\Lambda$=0.5')

om=0.3
omd=1-om

def f(z):
    return 1/(H*(om*(1+z)**3 + omd)**0.5)
y= (1+u)*(10**(-3))*c*[integrate.quad(f, 0, t)[0] for t in u]
plt.plot(u,y,label='$\Omega_o$=0.3, $\Omega_\Lambda$=0.7')

om=0.1
omd=1-om

def f(z):
    return 1/(H*(om*(1+z)**3 + omd)**0.5)
y= (1+u)*(10**(-3))*c*[integrate.quad(f, 0, t)[0] for t in u]
plt.plot(u,y,label='$\Omega_o$=0.1, $\Omega_\Lambda$=0.9')

om=0
omd=1-om

def f(z):
    return 1/(H*(om*(1+z)**3 + omd)**0.5)
y= (1+u)*(10**(-3))*c*[integrate.quad(f, 0, t)[0] for t in u]
plt.plot(u,y,label='$\Omega_o$=0, $\Omega_\Lambda$=1')
plt.minorticks_on()
plt.grid(which="minor",color="red", alpha=0.1)
plt.grid(color="black", alpha=0.2)
# print(u,y)


plt.legend()

# %% [markdown]
# # Plot Luminosity distance vs Redshift graph using the SCP union 2 Data

# %%
import numpy as np
import scipy as sp
from scipy import integrate
from scipy.integrate import quad
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']= (15,10)
c=3*(10**8)
H=70

a = np.loadtxt('data.txt')
x=a[:,0]
y=a[:,1]
d=10**((y+5)/5)*(10**(-6))
# print(x[100],d[100])
plt.plot(x,d, 'b.')
# plt.plot(x,d,'b.', ls='--')
xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r"Luminosity Distance ($D_L$) in Mpc")
thetitle=plt.title("Plot using the SCP union 2 Data"); thetitle.set_fontweight('bold')

# %% [markdown]
# # Finding Best Fit Values (Cosmology density parameters)

# %%
import numpy as np
from scipy import integrate
import scipy.optimize
import matplotlib.pyplot as plt


plt.rcParams['figure.figsize']= (15,10)

c=299792458
H=70

a = np.loadtxt('data.txt')
xlist=a[:,0]
ylist=a[:,1]
xdata=np.array(xlist)
ydata=np.array(ylist)
d=10**((ydata+5)/5)*(10**(-6))
plt.plot(xdata,d,'b.',label='SCP union 2 data')

parameter_initial = np.array([0.3])

def func(x,k):
    fn= lambda z: 1/(H*(k*(1+z)**3 + (1-k))**0.5)
    dis= ((1+x)*c*10**(-3)*[integrate.quad(fn, 0, t)[0] for t in x])
    return dis


parameter_optimal, cov = curve_fit(func, xdata, d,p0=parameter_initial)
y = func(xdata, *parameter_optimal)
plt.plot(xdata, y, '-', color= 'red', label='Best fit')

print('Omega_0=', parameter_optimal)
print("Omega_Lambda=", 1-parameter_optimal)
xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r"Luminosity Distance ($D_L$) in Mpc")
thetitle=plt.title("Luminosity Distance vs Redshift Graph"); thetitle.set_fontweight('bold')

# def f(z):
#     return 1/(H*(om*(1+z)**3 + omd)**0.5)
# y= (1+u)*c*[integrate.quad(f, 0, t)[0] for t in u]
# plt.plot(u,y)
plt.legend()
plt.show()
# Out:
# Omega_0= [0.2693478]
# Omega_Lambda= [0.7306522]

# %% [markdown]
# # Plot for various Hubble parameters

# %%
import numpy as np
from scipy import integrate
import scipy.optimize
import matplotlib.pyplot as plt


plt.rcParams['figure.figsize']= (15,10)

c=299792458
H=70

a = np.loadtxt('data.txt')
xlist=a[:,0]
ylist=a[:,1]
xdata=np.array(xlist)
ydata=np.array(ylist)
d=10**((ydata+5)/5)*(10**(-6))
plt.plot(xdata,d,'k.')

parameter_initial = np.array([0.3])

def func(x,k):
    fn= lambda z: 1/(H*(k*(1+z)**3 + (1-k))**0.5)
    dis= np.asarray((1+x)*c*10**(-3)*[integrate.quad(fn, 0, t)[0] for t in x])
    return dis


parameter_optimal, cov = scipy.optimize.curve_fit(func, xdata, d,p0=parameter_initial)
y = func(xdata, *parameter_optimal)
plt.plot(xdata, y, '-', color= 'red',label= "$H_0$=70")


xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r"Luminosity Distance ($D_L$) in Mpc")
thetitle=plt.title("Luminosity Distance vs Redshift Graph"); thetitle.set_fontweight('bold')

c=3*(10**8)
H=72

a = np.loadtxt('data.txt')
xlist=a[:,0]
ylist=a[:,1]
xdata=np.array(xlist)
ydata=np.array(ylist)
d=10**((ydata+5)/5)*(10**(-6))
plt.plot(xdata,d,'k.')

parameter_initial = np.array([0.3])

def func(x,k):
    fn= lambda z: 1/(H*(k*(1+z)**3 + (1-k))**0.5)
    dis= np.asarray((1+x)*c*10**(-3)*[integrate.quad(fn, 0, t)[0] for t in x])
    return dis


parameter_optimal, cov = scipy.optimize.curve_fit(func, xdata, d,p0=parameter_initial)
y = func(xdata, *parameter_optimal)
plt.plot(xdata, y, '-', color= 'green',label= "$H_0$=72")


c=3*(10**8)
H=68

a = np.loadtxt('data.txt')
xlist=a[:,0]
ylist=a[:,1]
xdata=np.array(xlist)
ydata=np.array(ylist)
d=10**((ydata+5)/5)*(10**(-6))
plt.plot(xdata,d,'k.')

parameter_initial = np.array([0.3])

def func(x,k):
    fn= lambda z: 1/(H*(k*(1+z)**3 + (1-k))**0.5)
    dis= np.asarray((1+x)*c*10**(-3)*[integrate.quad(fn, 0, t)[0] for t in x])
    return dis


parameter_optimal, cov = scipy.optimize.curve_fit(func, xdata, d,p0=parameter_initial)
y = func(xdata, *parameter_optimal)
plt.plot(xdata, y, '-', color= 'orange', label= "$H_0$=68")
plt.legend()
plt.show()
# def f(z):
#     return 1/(H*(om*(1+z)**3 + omd)**0.5)
# y= (1+u)*c*[integrate.quad(f, 0, t)[0] for t in u]
# plt.plot(u,y)

# %% [markdown]
# # Distance Modulus vs Redshift graph for various Cosmology density parameters

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting

z=np.arange(0.1,10,.1)

c=299792458 
H=70

def integrand(z,OM):
    return (1/H)*np.power(((OM*(1+z)**3)+(1-OM)),-0.5)

def curve(z,OM):
    I = [integrate.quad(integrand,0,i,args=(OM))[0] for i in z]
    return 5*np.log10((10**-3)*c*(1+z)*I)+25

plt.plot(z,curve(z,1), color="black",label= '$\Omega_o$=1, $\Omega_\Lambda$=0')
plt.plot(z,curve(z,0.7), color="blue",label= '$\Omega_o$=0.7, $\Omega_\Lambda$=0.3')
plt.plot(z,curve(z,0.5), color="red", label= '$\Omega_o$=0.5, $\Omega_\Lambda$=0.5')
plt.plot(z,curve(z,0.3), color="green", label= '$\Omega_o$=0.3, $\Omega_\Lambda$=0.7')
plt.plot(z,curve(z,0.1), color="y",label= '$\Omega_o$=0.1, $\Omega_\Lambda$=0.9')
plt.plot(z,curve(z,0), color="c",label= '$\Omega_o$=0, $\Omega_\Lambda$=1')


xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r"Distance Modulus (m-M)")
thetitle=plt.title("Distance Modulus vs Redshift plot for various density cosmological parameters");
thetitle.set_fontweight('bold')

plt.minorticks_on()
plt.grid(which="minor",color="red", alpha=0.1)
plt.grid(color="black", alpha=0.2)
plt.legend()
plt.show()

# %% [markdown]
# # Plot Distance Modulus vs Redshift graph using the SCP union 2 Data

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting

a = np.loadtxt('data.txt')
xlist=a[:,0]
ylist=a[:,1]
merror=a[:,2]


z=np.asarray(xlist)
m=np.asarray(ylist)

idx = np.argsort(z)
z = np.take(z, idx)
m = np.take(m, idx)



c=299792458 
H=70

# print(z[510],m[510])

plt.errorbar(xlist, ylist, yerr=merror, xerr=None, fmt='o', ecolor='black',elinewidth=2, capsize=5)


xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r"Distance Modulus (m-M)")
thetitle=plt.title("Distance Modulus vs Redshift plot using Data"); thetitle.set_fontweight('bold')

# %% [markdown]
# # Finding Best Fit Values (Cosmology density parameters)

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting

a = np.loadtxt('data.txt')
xlist=a[:,0]
ylist=a[:,1]
merror=a[:,2]


z=np.asarray(xlist)
m=np.asarray(ylist)

idx = np.argsort(z)
z = np.take(z, idx)
m = np.take(m, idx)

c=299792458 
# H=70

def integrand(z,H,OM):
    return (1/H)*np.power(((OM*(1+z)**3)+(1-OM)),-0.5)

def curve(z,H,OM):
    I = [integrate.quad(integrand,0,i,args=(H,OM))[0] for i in z]
    return 5*np.log10((10**-3)*c*(1+z)*I)+25

popts, pcov=curve_fit(curve,z,m, p0=(67,0.25))

# plt.plot(z,m,'o')

plt.errorbar(xlist, ylist, yerr=merror, color='#0000FF', xerr=None, fmt='.', 
             ecolor='black',elinewidth=2, capsize=5, label='SCP union 2 data')


# matplotlib.pyplot.errorbar(x, y, yerr=None, xerr=None, fmt='', ecolor=None, elinewidth=None, 
#                            capsize=None, barsabove=False, lolims=False, uplims=False, xlolims=False,
#                            xuplims=False, errorevery=1, capthick=None, *, data=None, **kwargs)



plt.plot(z,curve(z,*popts), color='red', label='Best fit')

# print('Hubble Constant=', popts[0])
print('Hubble Constant=',"%.3f" % popts[0])
print('Omega_0=', "%.3f" %popts[1])
print("Omega_Lambda=","%.3f" %(1-popts[1]) )
xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r"Distance Modulus (m-M)")
thetitle=plt.title("Distance Modulus vs Redshift Graph"); thetitle.set_fontweight('bold')




plt.legend()
plt.show()
# Out:
# Hubble Constant= 69.773
# Omega_0= 0.294
# Omega_Lambda= 0.706

# %% [markdown]
# # Residual graph

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting

a = np.loadtxt('data.txt')
xlist=a[:,0]
ylist=a[:,1]
merr=a[:,2]


z=np.asarray(xlist)
m=np.asarray(ylist)
merror=np.asarray(merr)

idx = np.argsort(z)
z = np.take(z, idx)
m = np.take(m, idx)
merror = np.take(merror, idx)

c=299792458 
# H=70

def integrand(z,H,OM):
    return (1/H)*np.power(((OM*(1+z)**3)+(1-OM)),-0.5)

def curve(z,H,OM):
    I = [integrate.quad(integrand,0,i,args=(H,OM))[0] for i in z]
    return 5*np.log10((10**-3)*c*(1+z)*I)+25

popts, pcov=curve_fit(curve,z,m, p0=(69,0.25))

# plt.plot(z,m,'o')


# matplotlib.pyplot.errorbar(x, y, yerr=None, xerr=None, fmt='', ecolor=None, elinewidth=None, 
#                            capsize=None, barsabove=False, lolims=False, uplims=False, xlolims=False,
#                            xuplims=False, errorevery=1, capthick=None, *, data=None, **kwargs)



y= curve(z,*popts)

mterror= y-m
mtherror=np.abs(mterror)
# print(mtherror)


plt.errorbar(z, mterror, yerr=merror, color='#6C7B8B', xerr=None, fmt='o', ecolor='#9FB6CD',elinewidth=2, capsize=5)


# plt.plot(z,curve(z,*popts))

# print('Omega_0=', popts)
# print("Omega_Lambda=", 1-popts)
# xlab = plt.xlabel(r"Redshift (Z)")
# ylab = plt.ylabel(r"Distance Modulus (m-M)")
# thetitle=plt.title("Distance Modulus vs Redshift Graph"); thetitle.set_fontweight('bold')

# zmerror=y-y

# plt.plot(z,zmerror,ls='--',color='k')

xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r'Residual distance modulus $\Delta$ (m-M)')
thetitle=plt.title("Difference between observed data points and fit to the data"); thetitle.set_fontweight('bold')



plt.show()

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting

a = np.loadtxt('data.txt')
xlist=a[:,0]
ylist=a[:,1]
merror=a[:,2]


z=np.asarray(xlist)
m=np.asarray(ylist)

idx = np.argsort(z)
z = np.take(z, idx)
m = np.take(m, idx)

c=299792458 
# H=70

def integrand(z,H,OM):
    return (1/H)*np.power(((OM*(1+z)**3)+(1-OM)),-0.5)

def curve(z,H,OM):
    I = [integrate.quad(integrand,0,i,args=(H,OM))[0] for i in z]
    return 5*np.log10((10**-3)*c*(1+z)*I)+25

popts, pcov=curve_fit(curve,z,m, p0=(69,0.25))

# plt.plot(z,m,'o')


# matplotlib.pyplot.errorbar(x, y, yerr=None, xerr=None, fmt='', ecolor=None, elinewidth=None, 
#                            capsize=None, barsabove=False, lolims=False, uplims=False, xlolims=False,
#                            xuplims=False, errorevery=1, capthick=None, *, data=None, **kwargs)



y= curve(z,*popts)

mterror= y-m
mtherror=np.abs(mterror)
# print(mtherror)


plt.errorbar(z, mterror, yerr=merror, color='#6C7B8B', xerr=None, 
             fmt='o', ecolor='#9FB6CD',elinewidth=2, capsize=5, alpha=0.28,label='Residual distance modulus')


# plt.plot(z,curve(z,*popts))

# print('Omega_0=', popts)
# print("Omega_Lambda=", 1-popts)
# xlab = plt.xlabel(r"Redshift (Z)")
# ylab = plt.ylabel(r"Distance Modulus (m-M)")
# thetitle=plt.title("Distance Modulus vs Redshift Graph"); thetitle.set_fontweight('bold')
H0=popts[0]

y2= curve(z,H0,0.1)
y3= curve(z,H0,0.15)
y4= curve(z,H0,0.27)
y5= curve(z,H0,0.5)
y6= curve(z,H0,0.75)
y1= curve(z,H0,1)



zmerror=y-y

zbmerror=(y2-y)
zcmerror=(y3-y)
zdmerror=(y4-y)
zemerror=(y5-y)
zfmerror=(y6-y)
zamerror=(y1-y)

plt.plot(z,zmerror,ls='--',color='k', label= 'Best fit values for desnity parameters')
plt.plot(z,zbmerror,ls='--',color='m', label= '$\Omega_o$=0.1, $\Omega_\Lambda$=0.9')
plt.plot(z,zcmerror,ls='--',color='b',label= '$\Omega_o$=0.15, $\Omega_\Lambda$=0.85')
plt.plot(z,zdmerror,ls='--',color='g', label= '$\Omega_o$=0.27, $\Omega_\Lambda$=0.73')
plt.plot(z,zemerror,ls='--',color='c', label= '$\Omega_o$=0.5, $\Omega_\Lambda$=0.5')
plt.plot(z,zfmerror,ls='--',color='y',label= '$\Omega_o$=0.75, $\Omega_\Lambda$=0.25')
plt.plot(z,zamerror,ls='--',color='r', label= '$\Omega_o$=1, $\Omega_\Lambda$=0')


xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r'Residual distance modulus $\Delta$ (m-M)')
thetitle=plt.title("Difference between values of m-M for various density parameters with best fit"); 
thetitle.set_fontweight('bold')


plt.legend()
plt.show()

# %% [markdown]
# # Importing Type Ia Supernovae Data from Berkeley Supernova Ia Program (BSNIP l)

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting


a = np.loadtxt('bsniplow.txt')
x1list=a[:,0]
# zerror=a[:,5]
y1list=a[:,7]
m1error=a[:,8]



b = np.loadtxt('bsnipsdss.txt')
x2list=b[:,0]
y2list=b[:,7]
m2error=b[:,8]


c = np.loadtxt('bsnipsnls.txt')
x3list=c[:,0]
y3list=c[:,7]
m3error=c[:,8]


d = np.loadtxt('bsniphst.txt')
x4list=d[:,0]
y4list=d[:,7]
m4error=d[:,8]



# z=np.asarray(xlist)
# m=np.asarray(ylist)

# idx = np.argsort(z)
# z = np.take(z, idx)
# m = np.take(m, idx)

c=299792458
H=70

# print(merror[0])


plt.errorbar(x1list, y1list, yerr=m1error, xerr=None, fmt='d',color='r', ecolor='black',elinewidth=2, 
             capsize=5)

plt.errorbar(x2list, y2list, yerr=m2error, xerr=None, fmt='d', color= 'g',ecolor='black',elinewidth=2, 
             capsize=5)

plt.errorbar(x3list, y3list, yerr=m3error, xerr=None, fmt='d', color= '#FF7D40',ecolor='black',elinewidth=2, 
             capsize=5)

plt.errorbar(x4list, y4list, yerr=m4error, xerr=None, fmt='d', color= 'b',ecolor='black',elinewidth=2, 
             capsize=5)

# plt.errorbar(xlist, ylist, yerr=None, xerr=None, fmt='.',ecolor='black', color='blue',elinewidth=2, capsize=5)

# plt.errorbar(xlistl, ylistl, yerr=None, xerr=None, fmt='.', color= 'g',ecolor='black',elinewidth=2, capsize=5)


xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r"Distance Modulus (m-M)")
thetitle=plt.title("Distance Modulus vs Redshift using the BSNIP l Data"); 
thetitle.set_fontweight('bold')


# plt.minorticks_on()
# plt.grid(which="minor",color="red", alpha=0.2)
# plt.grid(color="black", alpha=0.3)


plt.text(x1list[75], y1list[75],"Low-z",position=(0.05,34),fontsize=18, va='center',fontfamily='serif',color='r')
plt.text(x1list[75], y1list[75],"SDSS",position=(0.25,39.5),fontsize=18, va='center',fontfamily='serif', color= 'g')
plt.text(x1list[75], y1list[75],"SNLS",position=(0.7,42),fontsize=18, va='center',fontfamily='serif', color= '#FF7D40')
plt.text(x1list[75], y1list[75],"HST",position=(1.25,44),fontsize=18, va='center',fontfamily='serif', color= 'b')


plt.show()

# %% [markdown]
# # BEST FIT

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting


a = np.loadtxt('bsniplow.txt')
x1list=a[:,0]
# zerror=a[:,5]
y1list=a[:,7]
m1error=a[:,8]

f1=np.asarray(x1list)
g1=np.asarray(y1list)
m1error=np.asarray(m1error)



b = np.loadtxt('bsnipsdss.txt')
x2list=b[:,0]
y2list=b[:,7]
m2error=b[:,8]


f2=np.asarray(x2list)
g2=np.asarray(y2list)
m2error=np.asarray(m2error)


c = np.loadtxt('bsnipsnls.txt')
x3list=c[:,0]
y3list=c[:,7]
m3error=c[:,8]


f3=np.asarray(x3list)
g3=np.asarray(y3list)
m3error=np.asarray(m3error)


d = np.loadtxt('bsniphst.txt')
x4list=d[:,0]
y4list=d[:,7]
m4error=d[:,8]


f4=np.asarray(x4list)
g4=np.asarray(y4list)
m4error=np.asarray(m4error)


f5=np.append(f1,f2)
g5=np.append(g1,g2)
m1err=np.append(m1error,m2error)
f6=np.append(f3,f4)
g6=np.append(g3,g4)
m2err=np.append(m3error,m4error)
f7=np.append(f5,f6)
g7=np.append(g5,g6)
merr=np.append(m1err,m2err)




z=np.asarray(f7)
m=np.asarray(g7)
merror=merr



idx = np.argsort(z)
z = np.take(z, idx)
m = np.take(m, idx)
merror=np.take(merror, idx)

c=299792458
# H=70

# print(merror[0])



def integrand(z,H,OM):
    return (1/H)*np.power(((OM*(1+z)**3)+(1-OM)),-0.5)

def curve(z,H,OM):
    I = [integrate.quad(integrand,0,i,args=(H,OM))[0] for i in z]
    return 5*np.log10((10**-3)*c*(1+z)*I)+25

popts, pcov=curve_fit(curve,z,m, p0=(69,0.25))



plt.plot(z,curve(z,*popts), color='#BF3EFF', label='Best fit')



print('Hubble Constant=',"%.3f" %  popts[0])
print('Omega_0=', "%.3f" % popts[1])
print("Omega_Lambda=", "%.3f" % (1-popts[1]))

# print('Hubble Constant=',popts[0])
# print('Omega_0=',  popts[1])
# print("Omega_Lambda=", (1-popts[1]))



# print(z)
# print(m)
# print(curve(z,*popts))




plt.errorbar(x1list, y1list, yerr=m1error, xerr=None, fmt='d',color='r', ecolor='black',elinewidth=2, 
             capsize=5)

plt.errorbar(x2list, y2list, yerr=m2error, xerr=None, fmt='d', color= 'g',ecolor='black',elinewidth=2, 
             capsize=5)

plt.errorbar(x3list, y3list, yerr=m3error, xerr=None, fmt='d', color= '#FF7D40',ecolor='black',elinewidth=2, 
             capsize=5)

plt.errorbar(x4list, y4list, yerr=m4error, xerr=None, fmt='d', color= 'b',ecolor='black',elinewidth=2, 
             capsize=5)

# plt.errorbar(xlist, ylist, yerr=None, xerr=None, fmt='.',ecolor='black', color='blue',elinewidth=2, capsize=5)

# plt.errorbar(xlistl, ylistl, yerr=None, xerr=None, fmt='.', color= 'g',ecolor='black',elinewidth=2, capsize=5)


xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r"Distance Modulus (m-M)")
thetitle=plt.title("Distance Modulus vs Redshift using the BSNIP l Data"); 
thetitle.set_fontweight('bold')


# plt.minorticks_on()
# plt.grid(which="minor",color="red", alpha=0.2)
# plt.grid(color="black", alpha=0.3)


plt.text(x1list[75], y1list[75],"Low-z",position=(0.05,34),fontsize=18, va='center',fontfamily='serif',color='r')
plt.text(x1list[75], y1list[75],"SDSS",position=(0.25,39.5),fontsize=18, va='center',fontfamily='serif', color= 'g')
plt.text(x1list[75], y1list[75],"SNLS",position=(0.7,42),fontsize=18, va='center',fontfamily='serif', color= '#FF7D40')
plt.text(x1list[75], y1list[75],"HST",position=(1.25,44),fontsize=18, va='center',fontfamily='serif', color= 'b')

plt.legend()
plt.show()
# Out:
# Hubble Constant= 70.118
# Omega_0= 0.244
# Omega_Lambda= 0.756

# %% [markdown]
# # Residual Graph

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting

a = np.loadtxt('lossdata.txt')
xlist=a[:,0]
# zerror=a[:,5]
ylist=a[:,7]
merr=a[:,8]


z=np.asarray(xlist)
m=np.asarray(ylist)
merror=np.asarray(merr)
idx = np.argsort(z)
z = np.take(z, idx)
m = np.take(m, idx)
merror= np.take(merror, idx)


c=299792458 
H=70.11787069710803

def integrand(z,OM):
    return (1/H)*np.power(((OM*(1+z)**3)+(1-OM)),-0.5)

def curve(z,OM):
    I = [integrate.quad(integrand,0,i,args=(OM))[0] for i in z]
    return 5*np.log10((10**-3)*c*(1+z)*I)+25

popts, pcov=curve_fit(curve,z,m, p0=(0.25))

# plt.plot(z,m,'o')


# matplotlib.pyplot.errorbar(x, y, yerr=None, xerr=None, fmt='', ecolor=None, elinewidth=None, 
#                            capsize=None, barsabove=False, lolims=False, uplims=False, xlolims=False,
#                            xuplims=False, errorevery=1, capthick=None, *, data=None, **kwargs)



y= curve(z,*popts)

mterror= y-m
mtherror=np.abs(mterror)
# print(mtherror)


plt.errorbar(z, mterror, yerr=merror, color='#6C7B8B', xerr=None, fmt='o', ecolor='#9FB6CD',elinewidth=2, capsize=5)


# plt.plot(z,curve(z,*popts))

# print('Omega_0=', popts)
# print("Omega_Lambda=", 1-popts)
# xlab = plt.xlabel(r"Redshift (Z)")
# ylab = plt.ylabel(r"Distance Modulus (m-M)")
# thetitle=plt.title("Distance Modulus vs Redshift Graph"); thetitle.set_fontweight('bold')

# zmerror=y-y

# plt.plot(z,zmerror,ls='--',color='k')

xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r'Residual distance modulus $\Delta$ (m-M)')
thetitle=plt.title("Difference between observed data points and fit to the data"); thetitle.set_fontweight('bold')


plt.show()

# %% [markdown]
# # Importing Type Ia Supernovae Data from Pantheon

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting

a = np.loadtxt('datapa.txt')
xlist=a[:,0]
ylist=a[:,33]
merror=a[:,35]


z=np.asarray(xlist)
m=np.asarray(ylist)

# idx = np.argsort(z)
# z = np.take(z, idx)
# m = np.take(m, idx)

c=299792458
H=70

# print(merror[0])


# plt.plot(xlist,ylist,'o')

plt.errorbar(xlist, ylist, yerr=merror, xerr=None, fmt='o', ecolor='black',elinewidth=2, capsize=5)


xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r"Distance Modulus (m-M)")
thetitle=plt.title("Distance Modulus vs Redshift plot using Pantheon Data"); thetitle.set_fontweight('bold')


# plt.minorticks_on()
# plt.grid(which="minor",color="red", alpha=0.2)
# plt.grid(color="black", alpha=0.3)
plt.show()

# %% [markdown]
# # Find Best fit values (Cosmology density parameters)

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting

a = np.loadtxt('datapa.txt')
xlist=a[:,0]
ylist=a[:,33]
merror=a[:,35]


z=np.asarray(xlist)
m=np.asarray(ylist)

idx = np.argsort(z)
z = np.take(z, idx)
m = np.take(m, idx)

c=299792458
# H=70

# print(merror[0])


# plt.plot(xlist,ylist,'o')

plt.errorbar(xlist, ylist, yerr=merror, xerr=None, fmt='.', ecolor='black',elinewidth=2, capsize=5, label='Pantheon')


def integrand(z,H,OM):
    return (1/H)*np.power(((OM*(1+z)**3)+(1-OM)),-0.5)

def curve(z,H,OM):
    I = [integrate.quad(integrand,0,i,args=(H,OM))[0] for i in z]
    return 5*np.log10((10**-3)*c*(1+z)*I)+25

popts, pcov=curve_fit(curve,z,m, p0=(70,0.25))



plt.plot(z,curve(z,*popts), color='green', label='Best fit')



xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r"Distance Modulus (m-M)")
thetitle=plt.title("Distance Modulus vs Redshift plot using Pantehon Data"); thetitle.set_fontweight('bold')


print('Hubble Constant=', "%.3f" % popts[0])
print('Omega_0=', "%.3f" % popts[1])
print("Omega_Lambda=", "%.3f" % (1-popts[1]))


# plt.minorticks_on()
# plt.grid(which="minor",color="red", alpha=0.2)
# plt.grid(color="black", alpha=0.3)









plt.legend()
plt.show()
# Out:
# Hubble Constant= 69.832
# Omega_0= 0.290
# Omega_Lambda= 0.710

# %% [markdown]
# # Residual Graph

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting

a = np.loadtxt('datapa.txt')
xlist=a[:,0]
ylist=a[:,33]
merr=a[:,35]


z=np.asarray(xlist)
m=np.asarray(ylist)
merror=np.asarray(merr)
idx = np.argsort(z)
z = np.take(z, idx)
m = np.take(m, idx)
merror= np.take(merror, idx)


c=299792458 
H=69.83193276894637

def integrand(z,OM):
    return (1/H)*np.power(((OM*(1+z)**3)+(1-OM)),-0.5)

def curve(z,OM):
    I = [integrate.quad(integrand,0,i,args=(OM))[0] for i in z]
    return 5*np.log10((10**-3)*c*(1+z)*I)+25

popts, pcov=curve_fit(curve,z,m, p0=(0.25))

# plt.plot(z,m,'o')


# matplotlib.pyplot.errorbar(x, y, yerr=None, xerr=None, fmt='', ecolor=None, elinewidth=None, 
#                            capsize=None, barsabove=False, lolims=False, uplims=False, xlolims=False,
#                            xuplims=False, errorevery=1, capthick=None, *, data=None, **kwargs)



y= curve(z,*popts)

mterror= y-m
mtherror=np.abs(mterror)
# print(mtherror)


plt.errorbar(z, mterror, yerr=merror, color='#6C7B8B', xerr=None, fmt='o', ecolor='#9FB6CD',elinewidth=2, capsize=5)


# plt.plot(z,curve(z,*popts))

# print('Omega_0=', popts)
# print("Omega_Lambda=", 1-popts)
# xlab = plt.xlabel(r"Redshift (Z)")
# ylab = plt.ylabel(r"Distance Modulus (m-M)")
# thetitle=plt.title("Distance Modulus vs Redshift Graph"); thetitle.set_fontweight('bold')

# zmerror=y-y

# plt.plot(z,zmerror,ls='--',color='k')

xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r'Residual distance modulus $\Delta$ (m-M)')
thetitle=plt.title("Difference between observed data points and fit to the data"); thetitle.set_fontweight('bold')


plt.show()

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting

a = np.loadtxt('datapa.txt')
xlist=a[:,0]
ylist=a[:,33]
merr=a[:,35]


z=np.asarray(xlist)
m=np.asarray(ylist)
merror=np.asarray(merr)
idx = np.argsort(z)
z = np.take(z, idx)
m = np.take(m, idx)
merror= np.take(merror, idx)

c=299792458 
H=69.83193276894637

def integrand(z,OM):
    return (1/H)*np.power(((OM*(1+z)**3)+(1-OM)),-0.5)

def curve(z,OM):
    I = [integrate.quad(integrand,0,i,args=(OM))[0] for i in z]
    return 5*np.log10((10**-3)*c*(1+z)*I)+25

popts, pcov=curve_fit(curve,z,m, p0=(0.25))

# plt.plot(z,m,'o')


# matplotlib.pyplot.errorbar(x, y, yerr=None, xerr=None, fmt='', ecolor=None, elinewidth=None, 
#                            capsize=None, barsabove=False, lolims=False, uplims=False, xlolims=False,
#                            xuplims=False, errorevery=1, capthick=None, *, data=None, **kwargs)



y= curve(z,*popts)

mterror= y-m
mtherror=np.abs(mterror)
# print(mtherror)


plt.errorbar(z, mterror, yerr=merror, color='#6C7B8B', xerr=None, 
             fmt='o', ecolor='#9FB6CD',elinewidth=2, capsize=5, alpha=0.28,label='Residual distance modulus')


# plt.plot(z,curve(z,*popts))

# print('Omega_0=', popts)
# print("Omega_Lambda=", 1-popts)
# xlab = plt.xlabel(r"Redshift (Z)")
# ylab = plt.ylabel(r"Distance Modulus (m-M)")
# thetitle=plt.title("Distance Modulus vs Redshift Graph"); thetitle.set_fontweight('bold')


y2= curve(z,0.1)
y3= curve(z,0.15)
y4= curve(z,0.27)
y5= curve(z,0.5)
y6= curve(z,0.75)
y1= curve(z,1)



zmerror=y-y

zbmerror=(y2-y)
zcmerror=(y3-y)
zdmerror=(y4-y)
zemerror=(y5-y)
zfmerror=(y6-y)
zamerror=(y1-y)

plt.plot(z,zmerror,ls='--',color='k', label= 'Best fit values for desnity parameters')
plt.plot(z,zbmerror,ls='--',color='m', label= '$\Omega_o$=0.1, $\Omega_\Lambda$=0.9')
plt.plot(z,zcmerror,ls='--',color='b',label= '$\Omega_o$=0.15, $\Omega_\Lambda$=0.85')
plt.plot(z,zdmerror,ls='--',color='g', label= '$\Omega_o$=0.27, $\Omega_\Lambda$=0.73')
plt.plot(z,zemerror,ls='--',color='c', label= '$\Omega_o$=0.5, $\Omega_\Lambda$=0.5')
plt.plot(z,zfmerror,ls='--',color='y',label= '$\Omega_o$=0.75, $\Omega_\Lambda$=0.25')
plt.plot(z,zamerror,ls='--',color='r', label= '$\Omega_o$=1, $\Omega_\Lambda$=0')


xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r'Residual distance modulus $\Delta$ (m-M)')
thetitle=plt.title("Difference between values of m-M for various density parameters with best fit"); 
thetitle.set_fontweight('bold')


plt.legend()
plt.show()

# %% [markdown]
# # Importing Type Ia Supernovae Data from DES-SN3YR

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting

a = np.loadtxt('deslowc11.txt')
xlist=a[:,4]
zerror=a[:,5]
ylist=a[:,39]
merror=a[:,41]


z=np.asarray(xlist)
m=np.asarray(ylist)

# idx = np.argsort(z)
# z = np.take(z, idx)
# m = np.take(m, idx)

c=299792458
H=70

# print(merror[0])


# plt.plot(xlist,ylist,'o')

plt.errorbar(xlist, ylist, yerr=merror, xerr=zerror, fmt='o', ecolor='black',elinewidth=2, capsize=5)


xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r"Distance Modulus (m-M)")
thetitle=plt.title("Distance Modulus vs Redshift plot using DES-SN3YR Data"); thetitle.set_fontweight('bold')


# plt.minorticks_on()
# plt.grid(which="minor",color="red", alpha=0.1)
# plt.grid(color="black", alpha=0.2)
plt.show()

# %% [markdown]
# # Best fit to estimate cosmology density parameters

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting

a = np.loadtxt('deslowc11.txt')
xlist=a[:,4]
zerror=a[:,5]
ylist=a[:,39]
merror=a[:,41]

z=np.asarray(xlist)
m=np.asarray(ylist)

idx = np.argsort(z)
z = np.take(z, idx)
m = np.take(m, idx)

c=299792458
# H=70

# print(merror[0])


# plt.plot(xlist,ylist,'o')

plt.errorbar(xlist, ylist, yerr=merror, xerr=zerror, fmt='.', ecolor='black',elinewidth=2, capsize=5, label='DES-SN3YR')


def integrand(z,H,OM):
    return (1/H)*np.power(((OM*(1+z)**3)+(1-OM)),-0.5)

def curve(z,H,OM):
    I = [integrate.quad(integrand,0,i,args=(H,OM))[0] for i in z]
    return 5*np.log10((10**-3)*c*(1+z)*I)+25

popts, pcov=curve_fit(curve,z,m, p0=(70, 0.25))



plt.plot(z,curve(z,*popts), color='green', label='Best fit')



xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r"Distance Modulus (m-M)")
thetitle=plt.title("Distance Modulus vs Redshift plot using DES-SN3YR Data"); thetitle.set_fontweight('bold')


print('Hubble Constant=',"%.3f" % popts[0])
print('Omega_0=', "%.3f" % popts[1])
print("Omega_Lambda=","%.3f" % (1-popts[1]))


# plt.minorticks_on()
# plt.grid(which="minor",color="red", alpha=0.2)
# plt.grid(color="black", alpha=0.3)







plt.legend()
plt.show()
# Out:
# Hubble Constant= 69.706
# Omega_0= 0.320
# Omega_Lambda= 0.680

# %% [markdown]
# # Residual Graph

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting

a = np.loadtxt('deslowc11.txt')
xlist=a[:,4]
zerr=a[:,5]
ylist=a[:,39]
merr=a[:,41]


z=np.asarray(xlist)
m=np.asarray(ylist)
merror=np.asarray(merr)
zerror=np.asarray(zerr)
idx = np.argsort(z)
z = np.take(z, idx)
m = np.take(m, idx)
merror= np.take(merror, idx)
zerror= np.take(zerror, idx)

c=299792458 
H=69.70626242320324

def integrand(z,OM):
    return (1/H)*np.power(((OM*(1+z)**3)+(1-OM)),-0.5)

def curve(z,OM):
    I = [integrate.quad(integrand,0,i,args=(OM))[0] for i in z]
    return 5*np.log10((10**-3)*c*(1+z)*I)+25

popts, pcov=curve_fit(curve,z,m, p0=(0.25))

# plt.plot(z,m,'o')


# matplotlib.pyplot.errorbar(x, y, yerr=None, xerr=None, fmt='', ecolor=None, elinewidth=None, 
#                            capsize=None, barsabove=False, lolims=False, uplims=False, xlolims=False,
#                            xuplims=False, errorevery=1, capthick=None, *, data=None, **kwargs)



y= curve(z,*popts)

mterror= y-m
mtherror=np.abs(mterror)
# print(mtherror)


plt.errorbar(z, mterror, yerr=merror, color='#6C7B8B', xerr=zerror, fmt='o', ecolor='#9FB6CD',elinewidth=2, capsize=5)


# plt.plot(z,curve(z,*popts))

# print('Omega_0=', popts)
# print("Omega_Lambda=", 1-popts)
# xlab = plt.xlabel(r"Redshift (Z)")
# ylab = plt.ylabel(r"Distance Modulus (m-M)")
# thetitle=plt.title("Distance Modulus vs Redshift Graph"); thetitle.set_fontweight('bold')

# zmerror=y-y

# plt.plot(z,zmerror,ls='--',color='k')

xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r'Residual distance modulus $\Delta$ (m-M)')
thetitle=plt.title("Difference between observed data points and fit to the data"); thetitle.set_fontweight('bold')


plt.show()

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting

a = np.loadtxt('deslowc11.txt')
xlist=a[:,4]
zerr=a[:,5]
ylist=a[:,39]
merr=a[:,41]


z=np.asarray(xlist)
m=np.asarray(ylist)
merror=np.asarray(merr)
zerror=np.asarray(zerr)
idx = np.argsort(z)
z = np.take(z, idx)
m = np.take(m, idx)
merror= np.take(merror, idx)
zerror= np.take(zerror, idx)


c=299792458 
H=69.70626242320324

def integrand(z,OM):
    return (1/H)*np.power(((OM*(1+z)**3)+(1-OM)),-0.5)

def curve(z,OM):
    I = [integrate.quad(integrand,0,i,args=(OM))[0] for i in z]
    return 5*np.log10((10**-3)*c*(1+z)*I)+25

popts, pcov=curve_fit(curve,z,m, p0=(0.25))

# plt.plot(z,m,'o')


# matplotlib.pyplot.errorbar(x, y, yerr=None, xerr=None, fmt='', ecolor=None, elinewidth=None, 
#                            capsize=None, barsabove=False, lolims=False, uplims=False, xlolims=False,
#                            xuplims=False, errorevery=1, capthick=None, *, data=None, **kwargs)



y= curve(z,*popts)

mterror= y-m
mtherror=np.abs(mterror)
# print(mtherror)


plt.errorbar(z, mterror, yerr=merror, color='#6C7B8B', xerr=zerror, 
             fmt='o', ecolor='#9FB6CD',elinewidth=2, capsize=5, alpha=0.28,label='Residual distance modulus')


# plt.plot(z,curve(z,*popts))

# print('Omega_0=', popts)
# print("Omega_Lambda=", 1-popts)
# xlab = plt.xlabel(r"Redshift (Z)")
# ylab = plt.ylabel(r"Distance Modulus (m-M)")
# thetitle=plt.title("Distance Modulus vs Redshift Graph"); thetitle.set_fontweight('bold')


y2= curve(z,0.1)
y3= curve(z,0.15)
y4= curve(z,0.27)
y5= curve(z,0.5)
y6= curve(z,0.75)
y1= curve(z,1)



zmerror=y-y

zbmerror=(y2-y)
zcmerror=(y3-y)
zdmerror=(y4-y)
zemerror=(y5-y)
zfmerror=(y6-y)
zamerror=(y1-y)

plt.plot(z,zmerror,ls='--',color='k', label= 'Best fit values for desnity parameters')
plt.plot(z,zbmerror,ls='--',color='m', label= '$\Omega_o$=0.1, $\Omega_\Lambda$=0.9')
plt.plot(z,zcmerror,ls='--',color='b',label= '$\Omega_o$=0.15, $\Omega_\Lambda$=0.85')
plt.plot(z,zdmerror,ls='--',color='g', label= '$\Omega_o$=0.27, $\Omega_\Lambda$=0.73')
plt.plot(z,zemerror,ls='--',color='c', label= '$\Omega_o$=0.5, $\Omega_\Lambda$=0.5')
plt.plot(z,zfmerror,ls='--',color='y',label= '$\Omega_o$=0.75, $\Omega_\Lambda$=0.25')
plt.plot(z,zamerror,ls='--',color='r', label= '$\Omega_o$=1, $\Omega_\Lambda$=0')


xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r'Residual distance modulus $\Delta$ (m-M)')
thetitle=plt.title("Difference between values of m-M for various density parameters with best fit"); 
thetitle.set_fontweight('bold')


plt.legend()
plt.show()

# %% [markdown]
# # Import from CfA Supernova Type Ia data set

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting

a = np.loadtxt('cfa3con.txt')
xlist=a[:,0]
zerror=a[:,1]
ylist=a[:,8]
merror=a[:,9]


z=np.asarray(xlist)
m=np.asarray(ylist)

# idx = np.argsort(z)
# z = np.take(z, idx)
# m = np.take(m, idx)

c=299792458
H=65

# print(merror[0])


# plt.plot(xlist,ylist,'o')

plt.errorbar(xlist, ylist, yerr=merror, xerr=zerror, fmt='o', ecolor='black',elinewidth=2, capsize=5)


xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r"Distance Modulus (m-M)")
thetitle=plt.title("Distance Modulus vs Redshift plot using CFA3 Data"); thetitle.set_fontweight('bold')


# plt.minorticks_on()
# plt.grid(which="minor",color="red", alpha=0.1)
# plt.grid(color="black", alpha=0.2)
plt.show()

# %% [markdown]
# # BEST FIT

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting

a = np.loadtxt('cfa3con.txt')
xlist=a[:,0]
zerror=a[:,1]
ylist=a[:,8]
merror=a[:,9]


z=np.asarray(xlist)
m=np.asarray(ylist)

idx = np.argsort(z)
z = np.take(z, idx)
m = np.take(m, idx)

c=299792458
# H=65

# print(merror[0])


# plt.plot(xlist,ylist,'o')

plt.errorbar(xlist, ylist, yerr=merror, xerr=None, fmt='.', ecolor='black',elinewidth=2, capsize=5, label='CFA3')


def integrand(z,H,OM):
    return (1/H)*np.power(((OM*(1+z)**3)+(1-OM)),-0.5)

def curve(z,H,OM):
    I = [integrate.quad(integrand,0,i,args=(H,OM))[0] for i in z]
    return 5*np.log10((10**-3)*c*(1+z)*I)+25

popts, pcov=curve_fit(curve,z,m, p0=(70,0.25))



plt.plot(z,curve(z,*popts), color='green', label='Best fit')



xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r"Distance Modulus (m-M)")
thetitle=plt.title("Distance Modulus vs Redshift plot using CFA3 Data"); thetitle.set_fontweight('bold')

print('Hubble Constant=', "%.3f" % popts[0])
print('Omega_0=', "%.3f" %popts[1])
print("Omega_Lambda=","%.3f" % (1-popts[1]))


# plt.minorticks_on()
# plt.grid(which="minor",color="red", alpha=0.2)
# plt.grid(color="black", alpha=0.3)


plt.legend()
plt.show()
# Out:
# Hubble Constant= 64.425
# Omega_0= 0.305
# Omega_Lambda= 0.695

# %% [markdown]
# # Residual Graph

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting

a = np.loadtxt('cfa3con.txt')
xlist=a[:,0]
zerr=a[:,1]
ylist=a[:,8]
merr=a[:,9]


z=np.asarray(xlist)
m=np.asarray(ylist)
merror=np.asarray(merr)
idx = np.argsort(z)
z = np.take(z, idx)
m = np.take(m, idx)
merror= np.take(merror, idx)


c=299792458 
H=64.42500845887484

def integrand(z,OM):
    return (1/H)*np.power(((OM*(1+z)**3)+(1-OM)),-0.5)

def curve(z,OM):
    I = [integrate.quad(integrand,0,i,args=(OM))[0] for i in z]
    return 5*np.log10((10**-3)*c*(1+z)*I)+25

popts, pcov=curve_fit(curve,z,m, p0=(0.25))

# plt.plot(z,m,'o')


# matplotlib.pyplot.errorbar(x, y, yerr=None, xerr=None, fmt='', ecolor=None, elinewidth=None, 
#                            capsize=None, barsabove=False, lolims=False, uplims=False, xlolims=False,
#                            xuplims=False, errorevery=1, capthick=None, *, data=None, **kwargs)



y= curve(z,*popts)

mterror= y-m
mtherror=np.abs(mterror)
# print(mtherror)


plt.errorbar(z, mterror, yerr=merror, color='#6C7B8B', xerr=zerror, fmt='o', ecolor='#9FB6CD',elinewidth=2, capsize=5)


# plt.plot(z,curve(z,*popts))

# print('Omega_0=', popts)
# print("Omega_Lambda=", 1-popts)
# xlab = plt.xlabel(r"Redshift (Z)")
# ylab = plt.ylabel(r"Distance Modulus (m-M)")
# thetitle=plt.title("Distance Modulus vs Redshift Graph"); thetitle.set_fontweight('bold')

# zmerror=y-y

# plt.plot(z,zmerror,ls='--',color='k')

xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r'Residual distance modulus $\Delta$ (m-M)')
thetitle=plt.title("Difference between observed data points and fit to the data"); thetitle.set_fontweight('bold')


plt.show()

# %%
from matplotlib import pylab as plt

import numpy as np
import scipy.integrate as integrate
from scipy.optimize import curve_fit
plt.rcParams['figure.figsize']= (15,10)

# sorting of the data is not necessary but nicer when plotting

a = np.loadtxt('cfa3con.txt')
xlist=a[:,0]
zerr=a[:,1]
ylist=a[:,8]
merr=a[:,9]


z=np.asarray(xlist)
m=np.asarray(ylist)
merror=np.asarray(merr)
zerror=np.asarray(zerr)
idx = np.argsort(z)
z = np.take(z, idx)
m = np.take(m, idx)
merror= np.take(merror, idx)
zerror= np.take(zerror, idx)


c=299792458 
H=64.42500845887484

def integrand(z,OM):
    return (1/H)*np.power(((OM*(1+z)**3)+(1-OM)),-0.5)

def curve(z,OM):
    I = [integrate.quad(integrand,0,i,args=(OM))[0] for i in z]
    return 5*np.log10((10**-3)*c*(1+z)*I)+25

popts, pcov=curve_fit(curve,z,m, p0=(0.25))

# plt.plot(z,m,'o')


# matplotlib.pyplot.errorbar(x, y, yerr=None, xerr=None, fmt='', ecolor=None, elinewidth=None, 
#                            capsize=None, barsabove=False, lolims=False, uplims=False, xlolims=False,
#                            xuplims=False, errorevery=1, capthick=None, *, data=None, **kwargs)



y= curve(z,*popts)

mterror= y-m
mtherror=np.abs(mterror)
# print(mtherror)


plt.errorbar(z, mterror, yerr=merror, color='#6C7B8B', xerr=zerror, 
             fmt='o', ecolor='#9FB6CD',elinewidth=2, capsize=5, alpha=0.28,label='Residual distance modulus')


# plt.plot(z,curve(z,*popts))

# print('Omega_0=', popts)
# print("Omega_Lambda=", 1-popts)
# xlab = plt.xlabel(r"Redshift (Z)")
# ylab = plt.ylabel(r"Distance Modulus (m-M)")
# thetitle=plt.title("Distance Modulus vs Redshift Graph"); thetitle.set_fontweight('bold')


y2= curve(z,0.1)
y3= curve(z,0.15)
y4= curve(z,0.27)
y5= curve(z,0.5)
y6= curve(z,0.75)
y1= curve(z,1)



zmerror=y-y

zbmerror=(y2-y)
zcmerror=(y3-y)
zdmerror=(y4-y)
zemerror=(y5-y)
zfmerror=(y6-y)
zamerror=(y1-y)

plt.plot(z,zmerror,ls='--',color='k', label= 'Best fit values for desnity parameters')
plt.plot(z,zbmerror,ls='--',color='m', label= '$\Omega_o$=0.1, $\Omega_\Lambda$=0.9')
plt.plot(z,zcmerror,ls='--',color='b',label= '$\Omega_o$=0.15, $\Omega_\Lambda$=0.85')
plt.plot(z,zdmerror,ls='--',color='g', label= '$\Omega_o$=0.27, $\Omega_\Lambda$=0.73')
plt.plot(z,zemerror,ls='--',color='c', label= '$\Omega_o$=0.5, $\Omega_\Lambda$=0.5')
plt.plot(z,zfmerror,ls='--',color='y',label= '$\Omega_o$=0.75, $\Omega_\Lambda$=0.25')
plt.plot(z,zamerror,ls='--',color='r', label= '$\Omega_o$=1, $\Omega_\Lambda$=0')


xlab = plt.xlabel(r"Redshift (Z)")
ylab = plt.ylabel(r'Residual distance modulus $\Delta$ (m-M)')
thetitle=plt.title("Difference between values of m-M for various density parameters with best fit"); 
thetitle.set_fontweight('bold')


plt.legend()
plt.show()

# %% [markdown]
# # Cosmology Calculator

# %%
import numpy as np
from scipy import integrate
import scipy.optimize
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']= (15,25)



z=float(input("Enter the value of Redshift"))
om=float(input("Enter the value of matter density parameter"))

od=1-om
H0=float(input("Enter the value of Hubble parameter"))
Bage = 3.1536e16 
c=299792458
Mpc = 3.085677581e19 
T0=2.725

print("*"*20)
print("*"*20)

# The value of the Hubble parameter at the given redshift

Hz=(H0*(om*(1+z)**3 + od)**0.5)
xx="The value of the Hubble parameter at the given redshift"
print("The value of the Hubble parameter at the given redshift= {0} Km/s/Mpc".format("%.3f" % Hz))

print("*"*20)

# The present age of the universe, t_0

def f(x):
    return 1/(H0*(1+x)*(om*(1+x)**3 + od)**0.5)
y0= integrate.quad(f, 0, np.inf)[0]
c0= (10**3)*3.086*(10**16)
c1= 60*60*24*365
c3=(c0/c1)*(10**-9)
t0= y0*c3
print('The present age of the universe= {0} Gyr'.format("%.3f" % t0))

print("*"*20)


# The age of the universe at the given redshift

def g(y):
    return 1/(H0*(1+y)*(om*(1+y)**3 + od)**0.5)
a0= integrate.quad(g, z, np.inf)[0]
c0= (10**3)*3.086*(10**16)
c1= 60*60*24*365
c3=(c0/c1)*(10**-9)
t1= a0*c3
print('The age of the universe at the given redshift={0} Gyr'.format("%.3f" % t1))
# print(t1)

print("*"*20)


# The look-back time up to the given redshift

la= t0-t1
print('The look-back time up to the given redshift={0} Gyr'.format("%.3f" % la))
# print(la)

print("*"*20)

# Co-moving distance to the given redshift

def h(y):
    return c/(H0*(om*(1+y)**3 + od)**0.5)
b0= integrate.quad(h, 0, z)[0]
dc=(10**-3)*b0
print('Co-moving distance to the given redshift={0} Mpc'.format("%.3f" % dc))
# print(dc)

print("*"*20)


# angular diameter distance to the given redshift

def j(y):
    return c/(H0*(om*(1+y)**3 + od)**0.5)
b1= integrate.quad(j, 0, z)[0]
b2= 1/(1+z)
da= b1*b2*(10**-3)
print('angular diameter distance to the given redshift={0} Mpc'.format("%.3f" % da))
# print(da)

print("*"*20)

# luminosity distance to the given redshift

def k(y):
    return c/(H0*(om*(1+y)**3 + od)**0.5)
dl= (1+z)*(10**(-3))*integrate.quad(k, 0, z)[0]
print('luminosity distance to the given redshift={0} Mpc'.format("%.3f" % dl))
# print(dl)

print("*"*20)


# Temperature of the universe at the given redshift

Tz= T0*(1+z)
print('Temperature of the universe at the given redshift={0} K'.format("%.3f" % Tz))

print("*"*20)






 
     

H_0 = (H0 * Bage)/Mpc


def collapseMDE(Omega_0,t):
    maxa = (Omega_0 / (Omega_0 - 1))**(1./3) 
    fallt = (2*np.pi / (3*H_0)) * (1/(np.sqrt(Omega_0 - 1)))
    aa=np.sqrt(Omega_0 / (Omega_0 - 1))*np.sin((3./2)*H_0*t*np.sqrt(Omega_0 -1 ))
    a =np.sign(aa) * (np.abs(aa))**(2/3)
    age = (2. / (3*H_0*np.sqrt(Omega_0 - 1))) * np.arcsin(np.sqrt((Omega_0 - 1)/(Omega_0))) 
    return [a,maxa,fallt,age]

def foreverexpand(Omega_0,a):
    a_ml = (Omega_0 / (1 - Omega_0))**(1./3)    
    t = ((2 / (3*np.sqrt(1-Omega_0))) * np.log((a/a_ml)**(3/2) + np.sqrt( 1 + (a/a_ml)**(3))))/H_0
    age = (2. / (3*H_0*np.sqrt(1 - Omega_0 ))) * np.log((np.sqrt(1 - Omega_0) + 1)/np.sqrt(Omega_0))
    return [t, age, a_ml]



t = np.linspace(0,100,1000)

a = np.linspace(0,30,1000)

plt.subplot(3,1,1);plt.xlabel('$t-t_0$ (Gyr)')
plt.subplot(3,1,1);plt.ylabel('$a(t)$')

plt.subplot(3,1,1);plt.xlim(-20,100)
plt.subplot(3,1,1);plt.ylim(0,8)

plt.subplot(3,1,1);plt.title('Evolution of Matter + $\Lambda$ Universe Models',fontsize = 11)















def positivem(x,Omega_0):
    a0 = 0.5*(Omega_0 / (Omega_0-1))*(1-np.cos(x))    
    t0=(1/(2*H_0))*(Omega_0 / ((Omega_0-1)**(3/2)))*(x-np.sin(x))
    return [a0, t0]

theta= np.linspace(0,(2*np.pi))


[amm1,tmm1] = positivem(theta,1.1)



def negativek(x,Omega_0):
    p11 = 0.5*(Omega_0 / (1-Omega_0))*(np.cosh(x)-1)
    na01 =np.sign(p11) * (np.abs(p11))**(2/3)
    t11 = (1/(2*H_0))*(Omega_0 / ((1-Omega_0)**(3/2)))*(np.sinh(x)-x)  
    t1 =np.sign(t11) * (np.abs(t11))**(2/3)
    return [na01,t1]


eta= np.linspace(0,(700))











#**********************************************************************




def Monly(x,Omega_0):
    a1m = ((3/2)*H_0*ttt)**(2/3) 
    age1= (2/(3*H_0))   
    return [a1m, ttt, age1]


ttt = np.linspace(0,1000,1000)

# [a1a,t1t, age1a] = Monly(t,1)


# plt.xlabel('$t-t_0$ (Gyr)')
# plt.ylabel('$a(t)$')







def calone(x,Omega_0):
    a = H_0*ttt
    age3=(1/H_0)
    return [a, ttt, age3]


























#************************************************************************



if om <= 1:
    if om==1:
            [a1a,t1t, age1a] = Monly(ttt,1)
            plt.subplot(3,1,1); plt.plot((t1t-age1a),(a1a), color = 'g', label = 'Your Universe')
            [a3a,t3t, age3a] = calone(ttt,1)
            plt.subplot(3,1,2); plt.plot((t3t),(a3a), color = 'g', label = 'Your Universe')
            
            
    else:
        [tpl, age_pl, a_mlpl] = foreverexpand(om,a)
        plt.subplot(3,1,1);plt.plot(tpl- age_pl ,a, color = 'g', label = 'Your Universe')
    
        [am11,tm11] = negativek(eta,om)
        plt.subplot(3,1,2); plt.plot((tm11),(am11), color = 'g', label = 'Your Universe')
        
        

  
    
else:
    [a_nl,maxa_nl,t_c_nl,age_nl] = collapseMDE(om,t)
    plt.subplot(3,1,1);plt.plot(t - age_nl,a_nl, color = 'r', label = 'Your Universe')
    plt.subplot(3,1,1);plt.scatter((t_c_nl)/2-age_nl,maxa_nl,color = 'black',zorder = 10,s = 13)
    plt.subplot(3,1,1);plt.hlines(maxa_nl,-20,(t_c_nl)/2-age_nl,color = 'black',linestyle = ':',linewidth = 0.5)
    plt.subplot(3,1,1);plt.vlines((t_c_nl)/2-age_nl,0,maxa_nl,color = 'black',linestyle = ':',linewidth = 0.5)
    print('Time of crunch of the universe={0} Gyr'.format("%.3f" % t_c_nl))
    print("*"*20)
    print('Maximum value of scale factor for the given universe={0}'.format("%.3f" % maxa_nl))
    
    [amm2,tmm2] = positivem(theta,om)
    plt.subplot(3,1,2);plt.plot(tmm2,amm2, color = 'r', label = 'Your Universe')






[a_nl1,maxa_nl1,t_c_nl1,age_nl1] = collapseMDE(1.3,t)

[t_pl1, age_pl1, a_mlpl1] = foreverexpand(0.7,a)


plt.subplot(3,1,1);plt.xlabel('$t-t_0$ (Gyr)')
plt.subplot(3,1,1);plt.ylabel('$a(t)$')

plt.subplot(3,1,1);plt.xlim(-20,100)
plt.subplot(3,1,1);plt.ylim(0,8)

plt.subplot(3,1,1);plt.title('Evolution of Matter + $\Lambda$ Universe Models',fontsize = 11)


plt.subplot(3,1,1);plt.plot(t- age_nl1,a_nl1, color = 'navy',linestyle = '--',   label = '$\Omega_m = 1.3, \Omega_\Lambda = -0.3$')
plt.subplot(3,1,1);plt.plot(t_pl1- age_pl1,a, color = 'orange',linestyle = '--', label = '$\Omega_m = 0.7, \Omega_\Lambda = 0.3$')

plt.subplot(3,1,1);plt.scatter(0,1,color = 'black',zorder = 10,s = 13)
plt.subplot(3,1,1);plt.hlines(1,-20,0,color = 'black',linestyle = ':',linewidth = 0.5)
plt.subplot(3,1,1);plt.vlines(0,0,1,color = 'black',linestyle = ':',linewidth = 0.5)


plt.subplot(3,1,1);plt.scatter((t_c_nl1)/2-age_nl1,maxa_nl1,color = 'black',zorder = 10,s = 13)
plt.subplot(3,1,1);plt.hlines(maxa_nl1,-20,(t_c_nl1)/2-age_nl1,color = 'black',linestyle = ':',linewidth = 0.5)
plt.subplot(3,1,1);plt.vlines((t_c_nl1)/2-age_nl1,0,maxa_nl1,color = 'black',linestyle = ':',linewidth = 0.5)

plt.subplot(3,1,1);plt.legend()










[am1,tm1] = negativek(eta,0.9)
plt.subplot(3,1,2);plt.xlabel('$t$ (Gyr)')
plt.subplot(3,1,2);plt.ylabel('$a(t)$')

plt.subplot(3,1,2);plt.xlim(-30,1600)
plt.subplot(3,1,2);plt.ylim(0,15)



plt.subplot(3,1,2);plt.plot((tmm1),(amm1), color = 'navy', ls='--',label = '$\Omega_m = 1.1, \Omega_k = -0.1$')

plt.subplot(3,1,2);plt.plot((tm1),(am1), color = 'orange', ls='--',label = '$\Omega_m = 0.9, \Omega_k = 0.1 $')
# plt.subplot(2,1,2);plt.plot((tm11),(am11), color = 'r')
# plt.subplot(2,1,2);plt.plot((tm111),(am111), color = 'y')

plt.subplot(3,1,2);plt.title('If your universe were consisted only of Matter & curvature',fontsize = 11)
plt.subplot(3,1,2);plt.legend()










z=np.arange(0.1,10,.1)

c=299792458 


def integrand(z,OM):
    return (1/H_0)*np.power(((OM*(1+z)**3)+(1-OM)),-0.5)

def curve(z,OM):
    I = [integrate.quad(integrand,0,i,args=(OM))[0] for i in z]
    return 5*np.log10((10**-3)*c*(1+z)*I)+25

# plt.plot(z,curve(z,1), color="black",label= '$\Omega_o$=1, $\Omega_\Lambda$=0')
plt.subplot(3,1,3);plt.plot(z,curve(z,om), color="g",label= 'Graph for the given universe')
# plt.plot(z,curve(z,0.5), color="red", label= '$\Omega_o$=0.5, $\Omega_\Lambda$=0.5')
plt.subplot(3,1,3);plt.plot(z,curve(z,0.6), ls='--', color="navy", label= '$\Omega_o$=0.6, $\Omega_\Lambda$=0.4')
# plt.plot(z,curve(z,0.1), color="y",label= '$\Omega_o$=0.1, $\Omega_\Lambda$=0.9')
# plt.plot(z,curve(z,0), color="c",label= '$\Omega_o$=0, $\Omega_\Lambda$=1')


plt.subplot(3,1,3);plt.xlabel(r"Redshift (Z)")
plt.subplot(3,1,3);plt.ylabel(r"Distance Modulus (m-M)")
plt.subplot(3,1,3);plt.title("Distance Modulus vs Redshift plot for the given universe",fontsize = 11)



plt.subplot(3,1,3);plt.legend()




plt.show()
# Out:
# Enter the value of Redshift0.2
# Enter the value of matter density parameter0.3
# Enter the value of Hubble parameter70
# ********************
# ********************
# The value of the Hubble parameter at the given redshift= 77.267 Km/s/Mpc
# ********************
# The present age of the universe= 13.478 Gyr
# ********************
# The age of the universe at the given redshift=11.044 Gyr
# ********************
# The look-back time up to the given redshift=2.434 Gyr
# ********************
# Co-moving distance to the given redshift=816.723 Mpc
# ********************
# angular diameter distance to the given redshift=680.603 Mpc
# ********************
# luminosity distance to the given redshift=980.068 Mpc
# ********************
# Temperature of the universe at the given redshift=3.270 K
# ********************
